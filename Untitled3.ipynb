# %%
import json

import polars as pl

# %%
with open('/Users/chris.cestari/Downloads/unnested_local_discipline_incidents.json', 'r') as file:
    data = json.load(file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 2
#       1 with open('/Users/chris.cestari/Downloads/unnested_local_discipline_incidents.json', 'r') as file:
# ----> 2     data = json.load(file)
#
# File /opt/anaconda3/lib/python3.13/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
# ...

# %%
df = pl.read_json(data)
display(df)
